# %% [markdown]
# #**_1_Usecase_Explore_Notebooks_magic_commands_**
# ##A notebook to practice use cases with magic commands.
# ##_My name is Hemavarshini_
# ![WD36 Team Photo](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
--Task2: Create a volume namely usage_metrics using sql magic command %sql

CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %sql
SHOW VOLUMES;

# %%
# %run "/Workspace/Users/varshinihema999@gmail.com/4_child_nb_dataload_H"

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics/

# %%
# %fs
head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %python
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True)
df1.show()

# %%
# %py
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.write.saveAsTable("default.Sampdata_TB4")
display(df1)

# %%
# Clean column names by replacing spaces with underscores
df1_clean = df1.withColumnRenamed("Mobile Operating System", "mobile_operating_system") \
               .withColumnRenamed("Percent of Usage", "percent_of_usage")

df1_clean.show()

# %%
df1_clean.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
# %sql
select * from workspace.default.sampdata_tb4

# %%
# %python
a= 'hema'
print(a.upper())

# %%
# %pip install pandas

# %%
# %python

import pandas as pd
file_path = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
display(pd.read_csv(file_path))

# %%
# %sh
echo "Magic commands tasks completed"
